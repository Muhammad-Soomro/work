# %%
import pandas as pd

# %%
df = pd.read_csv('./offline_ids.csv')
with pd.option_context('display.max_columns', None):
    display(df)
# Out:
#                              offline_id       cm_id  camera_face source_type  \
# 0  e96a5109-0f98-4d2b-9f2c-265ad9facd50  2897315646  road_facing    recalled
# 1  6e750c6b-4fc3-4a13-b510-324e906af82b  2897929078  road_facing    recalled
#
#    fps  width  height added_by               tags cam_init_source  \
# 0    2   1280     720   soomro  testing_tt_v30102             api
# 1    2   1280     720   soomro  testing_tt_v30102             api
#
#   cam_init_model_version cam_init_model_type  gt_close_following  \
# 0                  0.2.1               cloud                   1
# 1                  0.2.1               cloud                   1
#
#    gt_mobile_usage  gt_seatbelt  gt_distraction  gt_unsafe_lane_change  \
# 0              NaN          NaN             NaN                    NaN
# 1              NaN          NaN             NaN                    NaN
#
#    cam_init_params  skip_motion_data  overwrite  gt_camera_obstruction  \
# ...
